# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Import the required libraries
import hvplot.pandas
import pandas as pd
import requests

# Import API keys
from api_keys import geoapify_key

# Turn off warning messages
import warnings
warnings.filterwarnings("ignore")

# %%
# Load CSV file created in WeatherPy
cities_df = pd.read_csv("output/weather_data_Marta.csv")

# Display top 5 rows
cities_df.head()
# Out:
#                    city  latitude  logitude  max_temperature  pressure  \
# 0            porto novo    6.4965    2.6036            25.54    1012.0
# 1            st. john's   47.5649  -52.7093            11.42    1002.0
# 2             grytviken  -54.2811  -36.5092            -7.19    1005.0
# 3  belo sur tsiribihina  -19.7000   44.5500            24.83    1015.0
# 4          punta arenas  -53.1500  -70.9167            -1.94    1028.0
#
#    humidity  wind_speed  cloudiness country
# 0      84.0        3.09       100.0      BJ
# 1      98.0        2.57       100.0      CA
# 2      79.0        3.86        15.0      GS
# 3      63.0        3.30        25.0      MG
# 4      93.0        1.03        20.0      CL

# %% [markdown]
# ## Map with all cities from the cities_df DataFrame where size is humidity

# %%
# %%capture --no-display

map_plot = cities_df.hvplot.points(
    "logitude",
    "latitude",
    geo = True,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500,
    size = "humidity",
    scale = 0.5, # Using a scale of 0.5 to make it easier to differentiate between cities that are near to each other
    color = "city"
)

# Display the map plot
map_plot
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [logitude,latitude]   (city,humidity)

# %% [markdown]
# ## cities_df DataFrame filtered to ideal vacation conditions

# %%
# Drop null values
df = cities_df.dropna()

# Ideal temperature: 16 to 25
# Ideal wind speed: under 7 m/s
# Ideal cloudiness: under 5%
filt = (df.max_temperature >= 16) & (df.max_temperature < 25) & (df.wind_speed < 7) & (df.cloudiness < 5)
vac_df = df.loc[filt]

# Display filtered DF with ideal vacation conditions
vac_df
# Out:
#                        city  latitude  logitude  max_temperature  pressure  \
# 28                   bethel   41.3712  -73.4140            23.53    1012.0
# 41                    crane   31.3974 -102.3501            24.80    1008.0
# 98                carnarvon  -24.8667  113.6333            21.99    1020.0
# 138                  gwanda  -20.9333   29.0000            24.46    1018.0
# 140            dalandzadgad   43.5708  104.4250            16.01    1015.0
# 144                 toliara  -23.3500   43.6667            24.08    1017.0
# 203               amboasary  -25.0333   46.3833            22.35    1017.0
# 222               belyy yar   53.6039   91.3903            16.94    1008.0
# 232                  bobrov   51.0961   40.0333            19.44    1029.0
# 249           nizhnedevitsk   51.5419   38.3657            16.97    1029.0
# 252       san juan bautista  -14.0108  -75.7358            22.91    1014.0
# 253               springbok  -29.6643   17.8865            23.49    1018.0
# 290         plettenberg bay  -34.0527   23.3716            18.26    1019.0
# 309                beykonak   36.3257   30.3030            23.19    1008.0
# 324                   orsta   62.2029    6.1272            24.10    1020.0
# 332                scituate   42.1959  -70.7259            22.44    1012.0
# 333                karratha  -20.7377  116.8463            24.47    1017.0
# 378                 urangan  -25.3000  152.9000            17.33    1020.0
# 384                 tsiombe  -25.3000   45.4833            21.74    1017.0
# 398                  taltal  -25.4000  -70.4833            17.02    1019.0
# 451                  broome   42.2506  -75.8330            23.51     997.0
# 486        muroto-misakicho   33.2833  134.1500            20.64    1016.0
# 497                 yeppoon  -23.1333  150.7333            17.92    1022.0
# 506              dadeldhura   29.2984   80.5806            24.42    1004.0
# 526                 iquique  -20.2208  -70.1431            18.02    1018.0
# 534         siqueira campos  -23.6889  -49.8339            19.63    1020.0
# 544                calvinia  -31.4707   19.7760            21.93    1019.0
# 560  saint-mandrier-sur-mer   43.0780    5.9290            21.91    1015.0
#
#      humidity  wind_speed  cloudiness country
# 28       56.0        4.12         0.0      US
# 41       40.0        3.32         0.0      US
# 98       78.0        6.86         0.0      AU
# 138      28.0        3.99         2.0      ZW
# 140      22.0        4.95         0.0      MN
# 144      64.0        5.11         0.0      MG
# 203      77.0        2.82         0.0      MG
# 222      63.0        5.00         0.0      RU
# 232      41.0        3.28         0.0      RU
# 249      43.0        2.61         1.0      RU
# 252      47.0        2.73         0.0      PE
# 253      19.0        3.12         0.0      ZA
# 290      69.0        1.06         2.0      ZA
# 309      56.0        3.14         0.0      TR
# 324      60.0        2.57         0.0      NO
# 332      48.0        3.09         0.0      US
# 333      44.0        1.90         0.0      AU
# 378      91.0        1.79         0.0      AU
# 384      76.0        4.23         0.0      MG
# 398      72.0        2.50         2.0      CL
# 451      58.0        2.57         0.0      US
# 486      64.0        4.55         1.0      JP
# 497      83.0        5.02         2.0      AU
# 506      52.0        2.13         0.0      NP
# 526      66.0        2.97         0.0      CL
# 534      58.0        1.87         2.0      BR
# 544      22.0        5.67         0.0      ZA
# 560      71.0        6.17         0.0      FR

# %% [markdown]
# ## Create hotel_df

# %%
# New df created with the city, country, latitude, longitude, and humidity columns from vac_df
hotel_df = vac_df[["city", "country", "latitude", "logitude", "humidity"]].copy()

# Adding an empty column to copy_df; code from Carsten on https://stackoverflow.com/a/57293727/23471668
hotel_df["hotel_name"] = pd.Series(dtype="object")

# Display new DataFrame
hotel_df
# Out:
#                        city country  latitude  logitude  humidity hotel_name
# 28                   bethel      US   41.3712  -73.4140      56.0        NaN
# 41                    crane      US   31.3974 -102.3501      40.0        NaN
# 98                carnarvon      AU  -24.8667  113.6333      78.0        NaN
# 138                  gwanda      ZW  -20.9333   29.0000      28.0        NaN
# 140            dalandzadgad      MN   43.5708  104.4250      22.0        NaN
# 144                 toliara      MG  -23.3500   43.6667      64.0        NaN
# 203               amboasary      MG  -25.0333   46.3833      77.0        NaN
# 222               belyy yar      RU   53.6039   91.3903      63.0        NaN
# 232                  bobrov      RU   51.0961   40.0333      41.0        NaN
# 249           nizhnedevitsk      RU   51.5419   38.3657      43.0        NaN
# 252       san juan bautista      PE  -14.0108  -75.7358      47.0        NaN
# 253               springbok      ZA  -29.6643   17.8865      19.0        NaN
# 290         plettenberg bay      ZA  -34.0527   23.3716      69.0        NaN
# 309                beykonak      TR   36.3257   30.3030      56.0        NaN
# 324                   orsta      NO   62.2029    6.1272      60.0        NaN
# 332                scituate      US   42.1959  -70.7259      48.0        NaN
# 333                karratha      AU  -20.7377  116.8463      44.0        NaN
# 378                 urangan      AU  -25.3000  152.9000      91.0        NaN
# 384                 tsiombe      MG  -25.3000   45.4833      76.0        NaN
# 398                  taltal      CL  -25.4000  -70.4833      72.0        NaN
# 451                  broome      US   42.2506  -75.8330      58.0        NaN
# 486        muroto-misakicho      JP   33.2833  134.1500      64.0        NaN
# 497                 yeppoon      AU  -23.1333  150.7333      83.0        NaN
# 506              dadeldhura      NP   29.2984   80.5806      52.0        NaN
# 526                 iquique      CL  -20.2208  -70.1431      66.0        NaN
# 534         siqueira campos      BR  -23.6889  -49.8339      58.0        NaN
# 544                calvinia      ZA  -31.4707   19.7760      22.0        NaN
# 560  saint-mandrier-sur-mer      FR   43.0780    5.9290      71.0        NaN

# %% [markdown]
# ## Closest hotel within 10,000 meters of the coordinates

# %%
# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    base_url = "https://api.geoapify.com/v2/places"
        
    # Set the parameters for the type of place
    categories = "accommodation.hotel"
    radius = 10000
    
    # Set the parameters for the type of search
    filters = f"circle:{row.logitude},{row.latitude},{radius}"
    bias = f"proximity:{row.logitude},{row.latitude}"
    limit = 5
    
    # set up a parameters dictionary
    params = {
        "categories":categories,
        "limit":limit,
        "filter":filters,
        "bias":bias,
        "apiKey":geoapify_key    
    }
    
    # Step 2:
    response = requests.get(base_url, params=params)
    
    # Step 3: 
    status_code = response.status_code
    
    # Step 4: 
    if status_code == 200:
        data = response.json()
    else:
        data = {} # failed request
    
    # Step 5: extraction
    results = data.get("features", [])
    
    # safe extraction for first item in list
    if len(results) > 0:
        result = results[0]
    else:
        result = {}
    
    try:
        # extract safely the data that we care about from first result
        prop = result.get("properties", {})
        
        # Using the get function, if there is no "name", will return "No hotel found"
        name = prop.get("datasource", {}).get("raw", {}).get("name", "No hotel found") 

        # Add the name to the hotel_df DataFrame
        hotel_df.loc[index, "hotel_name"] = name
    except:
        pass

    print(f"{hotel_df.loc[index, 'city']} - nearest hotel: {hotel_df.loc[index, 'hotel_name']}")

        
# Display updated df
hotel_df
# Out:
# bethel - nearest hotel: Hampton Inn Danbury
# crane - nearest hotel: No hotel found
# carnarvon - nearest hotel: No hotel found
# gwanda - nearest hotel: No hotel found
# dalandzadgad - nearest hotel: Хан Уул буудал
# toliara - nearest hotel: Ambary
# amboasary - nearest hotel: No hotel found
# belyy yar - nearest hotel: No hotel found
# bobrov - nearest hotel: Бобров
# nizhnedevitsk - nearest hotel: No hotel found
# san juan bautista - nearest hotel: Hacienda San Juan Resort & Spa
# springbok - nearest hotel: Elkoweru Guesthouse
# plettenberg bay - nearest hotel: Milkwood Manor
# beykonak - nearest hotel: Uyguluma Oteli
# orsta - nearest hotel: Hotel Ivar Aasen
# scituate - nearest hotel: The Inn at Scituate Harbor
# karratha - nearest hotel: Karratha International Hotel
# urangan - nearest hotel: Ramada
# tsiombe - nearest hotel: No hotel found
# taltal - nearest hotel: Hostería Taltal
# broome - nearest hotel: No hotel found
# muroto-misakicho - nearest hotel: 民宿うらしま
# yeppoon - nearest hotel: Blossom's on Seaspray
# dadeldhura - nearest hotel: No hotel found
# iquique - nearest hotel: Hostal Vivar
# siqueira campos - nearest hotel: No hotel found
# calvinia - nearest hotel: No hotel found
# saint-mandrier-sur-mer - nearest hotel: Le Barock
#                        city country  latitude  logitude  humidity  \
# 28                   bethel      US   41.3712  -73.4140      56.0
# 41                    crane      US   31.3974 -102.3501      40.0
# 98                carnarvon      AU  -24.8667  113.6333      78.0
# 138                  gwanda      ZW  -20.9333   29.0000      28.0
# 140            dalandzadgad      MN   43.5708  104.4250      22.0
# 144                 toliara      MG  -23.3500   43.6667      64.0
# 203               amboasary      MG  -25.0333   46.3833      77.0
# 222               belyy yar      RU   53.6039   91.3903      63.0
# 232                  bobrov      RU   51.0961   40.0333      41.0
# 249           nizhnedevitsk      RU   51.5419   38.3657      43.0
# 252       san juan bautista      PE  -14.0108  -75.7358      47.0
# 253               springbok      ZA  -29.6643   17.8865      19.0
# 290         plettenberg bay      ZA  -34.0527   23.3716      69.0
# 309                beykonak      TR   36.3257   30.3030      56.0
# 324                   orsta      NO   62.2029    6.1272      60.0
# 332                scituate      US   42.1959  -70.7259      48.0
# 333                karratha      AU  -20.7377  116.8463      44.0
# 378                 urangan      AU  -25.3000  152.9000      91.0
# 384                 tsiombe      MG  -25.3000   45.4833      76.0
# 398                  taltal      CL  -25.4000  -70.4833      72.0
# 451                  broome      US   42.2506  -75.8330      58.0
# 486        muroto-misakicho      JP   33.2833  134.1500      64.0
# 497                 yeppoon      AU  -23.1333  150.7333      83.0
# 506              dadeldhura      NP   29.2984   80.5806      52.0
# 526                 iquique      CL  -20.2208  -70.1431      66.0
# 534         siqueira campos      BR  -23.6889  -49.8339      58.0
# 544                calvinia      ZA  -31.4707   19.7760      22.0
# 560  saint-mandrier-sur-mer      FR   43.0780    5.9290      71.0
#
#                          hotel_name
# 28              Hampton Inn Danbury
# 41                   No hotel found
# 98                   No hotel found
# 138                  No hotel found
# 140                  Хан Уул буудал
# 144                          Ambary
# 203                  No hotel found
# 222                  No hotel found
# 232                          Бобров
# 249                  No hotel found
# 252  Hacienda San Juan Resort & Spa
# 253             Elkoweru Guesthouse
# 290                  Milkwood Manor
# 309                  Uyguluma Oteli
# 324                Hotel Ivar Aasen
# 332      The Inn at Scituate Harbor
# 333    Karratha International Hotel
# 378                          Ramada
# 384                  No hotel found
# 398                 Hostería Taltal
# 451                  No hotel found
# 486                          民宿うらしま
# 497           Blossom's on Seaspray
# 506                  No hotel found
# 526                    Hostal Vivar
# 534                  No hotel found
# 544                  No hotel found
# 560                       Le Barock

# %%
# %%capture --no-display

hotel_plot = hotel_df.hvplot.points(
    "logitude",
    "latitude",
    geo = True,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500,
    size = "humidity",
    color = "city",
    hover_cols = ["hotel_name", "country"]
)

# Display the map plot
hotel_plot
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [logitude,latitude]   (city,humidity,hotel_name,country)
